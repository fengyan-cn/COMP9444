# %%
from transformers import pipeline
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
classifier = pipeline("sentiment-analysis", device=device)
res = classifier("have a nice day!")
res
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'POSITIVE', 'score': 0.9998751878738403}]

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
def img2text(path:str):
    image_to_text = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base", device=device)
    text = image_to_text(path)[0]["generated_text"]
    return text

pic_path = "G:\\idle\\twitter\\40.jpg"
pic = Image.open(pic_path)
plt.imshow(pic)
plt.axis("off")
plt.show()
print(img2text(pic_path))
# Out:
# a woman in a white bikini is sitting on a wooden bench

# %%
from langchain import PromptTemplate, OpenAI, LLMChain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from langchain import PromptTemplate, OpenAI, LLMChain
#
# File c:\Users\learn\.conda\envs\pytorch_comp9444\Lib\site-packages\langchain\__init__.py:190, in __getattr__(name)
#     188     return Modal
#     189 elif name == "OpenAI":
# --> 190     from langchain_community.llms import OpenAI
#     192     _warn_on_import(name, replacement="langchain_community.llms.OpenAI")
#     194     return OpenAI
#
# ModuleNotFoundError: No module named 'langchain_community'
